# %%
def createList(num1, num2): 
  
    if (num1 == num2): 
        return r1 
  
    else: 
  
        ids = [] 
  
        while(num1 < num2+1 ): 
              
            ids.append(num1) 
            num1 += 200
        return ids 
      
# Driver Code 
num1, num2 = 4000, 10000
print(createList(num1, num2))
# Out:
# [4000, 4200, 4400, 4600, 4800, 5000, 5200, 5400, 5600, 5800, 6000, 6200, 6400, 6600, 6800, 7000, 7200, 7400, 7600, 7800, 8000, 8200, 8400, 8600, 8800, 9000, 9200, 9400, 9600, 9800, 10000]

# %%
product_ids = [5010, 5011, 5012, 5013, 5014, 5015, 5016, 5017, 5018, 5019, 5020, 5021, 5022, 5023, 5024, 5025, 5026, 5027, 5028, 5029, 5030, 5031, 5032, 5033, 5034, 5035, 5036, 5037, 5038, 5039, 5040]

# %%
amount = [4000, 4200, 4400, 4600, 4800, 5000, 5200, 5400, 5600, 5800, 6000, 6200, 6400, 6600, 6800, 7000, 7200, 7400, 7600, 7800, 8000, 8200, 8400, 8600, 8800, 9000, 9200, 9400, 9600, 9800, 10000]

# %%
area_codes = [900100, 900101, 900102, 900103, 900104, 900105, 900106, 900107, 900108, 900109, 900110, 900111, 900112, 900113, 900114, 900115, 900116, 900117, 900118, 900119, 900120, 900121, 900122, 900123, 900124, 900125, 900126, 900127, 900128, 900129, 900130, 900131, 900132, 900133, 900134, 900135, 900136, 900137, 900138, 900139, 900140, 900141, 900142, 900143, 900144, 900145, 900146, 900147, 900148, 900149, 900150, 900151, 900152, 900153, 900154, 900155, 900156, 900157, 900158, 900159, 900160, 900161, 900162, 900163, 900164, 900165, 900166, 900167, 900168, 900169, 900170, 900171, 900172, 900173, 900174, 900175, 900176, 900177, 900178, 900179, 900180, 900181, 900182, 900183, 900184, 900185, 900186, 900187, 900188, 900189, 900190, 900191, 900192, 900193, 900194, 900195, 900196, 900197, 900198, 900199, 900200]

# %%
sales_ids =[600050, 600051, 600052, 600053, 600054, 600055, 600056, 600057, 600058, 600059, 600060, 600061, 600062, 600063, 600064, 600065, 600066, 600067, 600068, 600069, 600070, 600071, 600072, 600073, 600074, 600075, 600076, 600077, 600078, 600079, 600080, 600081, 600082, 600083, 600084, 600085, 600086, 600087, 600088, 600089, 600090, 600091, 600092, 600093, 600094, 600095, 600096, 600097, 600098, 600099, 600100, 600101, 600102, 600103, 600104, 600105, 600106, 600107, 600108, 600109, 600110, 600111, 600112, 600113, 600114, 600115, 600116, 600117, 600118, 600119, 600120, 600121, 600122, 600123, 600124, 600125, 600126, 600127, 600128, 600129, 600130, 600131, 600132, 600133, 600134, 600135, 600136, 600137, 600138, 600139, 600140, 600141, 600142, 600143, 600144, 600145, 600146, 600147, 600148, 600149, 600150, 600151, 600152, 600153, 600154, 600155, 600156, 600157, 600158, 600159, 600160, 600161, 600162, 600163, 600164, 600165, 600166, 600167, 600168, 600169, 600170, 600171, 600172, 600173, 600174, 600175, 600176, 600177, 600178, 600179, 600180, 600181, 600182, 600183, 600184, 600185, 600186, 600187, 600188, 600189, 600190, 600191, 600192, 600193, 600194, 600195, 600196, 600197, 600198, 600199, 600200]

# %%
import random
import json
json_array = []
count = 0

# %%
while count <=1000:
    output={}
    output["dealAmount"] = random.choice(amount)
    output["areaCode"] = random.choice(area_codes)
    output["salesRepId"] = random.choice(sales_ids)
    output["productId"] = random.choice(product_ids)
    json_value = json.dumps(output)
    json_array.append(json_value)
    count = count+1

# %%
print(json_array)
# Out:
# ['{"dealAmount": 4200, "areaCode": 900146, "salesRepId": 600198, "productId": 5025}', '{"dealAmount": 8800, "areaCode": 900167, "salesRepId": 600198, "productId": 5011}', '{"dealAmount": 8600, "areaCode": 900103, "salesRepId": 600116, "productId": 5032}', '{"dealAmount": 5400, "areaCode": 900146, "salesRepId": 600134, "productId": 5015}', '{"dealAmount": 8000, "areaCode": 900151, "salesRepId": 600105, "productId": 5026}', '{"dealAmount": 5000, "areaCode": 900174, "salesRepId": 600089, "productId": 5031}', '{"dealAmount": 7200, "areaCode": 900177, "salesRepId": 600059, "productId": 5016}', '{"dealAmount": 5400, "areaCode": 900166, "salesRepId": 600150, "productId": 5032}', '{"dealAmount": 5600, "areaCode": 900165, "salesRepId": 600141, "productId": 5014}', '{"dealAmount": 9200, "areaCode": 900196, "salesRepId": 600132, "productId": 5039}', '{"dealAmount": 7400, "areaCode": 900170, "salesRepId": 600138, "productId": 5018}', '{"dealAmount": 9800, "areaCode": 900139, "salesRepId": 600148
# ...
